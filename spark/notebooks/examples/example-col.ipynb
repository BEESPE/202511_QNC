# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when, upper

# %%
spark = SparkSession.builder.appName("ColExampleApp").getOrCreate()

# %%
df1 = spark.createDataFrame([(1, "Alice"), (2, "Bob")], ["id", "value"]).alias("t1")
df2 = spark.createDataFrame([(1, "X"), (2, "Y")], ["id", "value"]).alias("t2")

joined = df1.join(df2, df1["id"] == df2["id"])

result = joined.select(df2["value"])
result.show()
# Out:
# +-----+
# |value|
# +-----+
# |    X|
# |    Y|
# +-----+

# %%
data = [(1, "Alice", 20), (2, "Bob", 11), (3, "Charlie", 30)]
columns = ["id", "name", "age"]

if_expr = when(col('age') < 18, 'underage').otherwise('adult')
df3 = spark.createDataFrame(data, columns).withColumn('age_category', if_expr)
df3.show()
# Out:
# +---+-------+---+------------+
# | id|   name|age|age_category|
# +---+-------+---+------------+
# |  1|  Alice| 20|       adult|
# |  2|    Bob| 11|    underage|
# |  3|Charlie| 30|       adult|
# +---+-------+---+------------+

# %%
result = joined.withColumn("flag", when(df1["id"] > 1, 1).otherwise(0)).filter(joined["flag"] > 0)

result.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result = joined.withColumn("flag", when(df1["id"] > 1, 1).otherwise(0)).filter(joined["flag"] > 0)
#       3 result.show()
#
# File /usr/local/spark/python/pyspark/sql/dataframe.py:3074, in DataFrame.__getitem__(self, item)
#    3002 """Returns the column as a :class:`Column`.
#    3003
#    3004 .. versionadded:: 1.3.0
#    (...)
#    3071 +---+----+
#    3072 """
#    3073 if isinstance(item, str):
# -> 3074     jc = self._jdf.apply(item)
#    3075     return Column(jc)
#    3076 elif isinstance(item, Column):
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/spark/python/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `flag` cannot be resolved. Did you mean one of the following? [`id`, `value`, `id`, `value`].

# %%
df3.withColumn("name", upper(df3["name"])).filter(df3["name"] == "ALICE").toPandas()
# Out:
# Empty DataFrame
# Columns: [id, name, age, age_category]
# Index: []

# %%
df3.withColumn("name", upper(df3["name"])).filter(col("name") == "ALICE").toPandas()
# Out:
#    id   name  age age_category
# 0   1  ALICE   20        adult
